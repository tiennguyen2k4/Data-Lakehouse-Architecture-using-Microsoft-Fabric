# %%
import json

TABLE_NAME = "shift"

# Schema dạng dictionary để dễ convert sang JSON
SCHEMA = {
    "fields": [
        {"name": "ShiftID", "type": "IntegerType", "nullable": True},
        {"name": "Name", "type": "StringType", "nullable": True},
        {"name": "StartTime", "type": "StringType", "nullable": True},
        {"name": "EndTime", "type": "StringType", "nullable": True},
        {"name": "ModifiedDate", "type": "TimestampType", "nullable": True}
    ]
}

PRIMARY_KEYS = "ShiftID"
# Out:
# StatementMeta(, 2d6bf88e-aad1-4d50-932e-b3da6cb0f5b0, 3, Finished, Available, Finished)

# %%
print(f"Bắt đầu incremental load bảng: {TABLE_NAME}")

schema_json = json.dumps(SCHEMA)

result = mssparkutils.notebook.run(
    path = "Get Data From Supabase Incremental load",
    timeout_seconds = 300,
    arguments = {
        "table_name": TABLE_NAME,
        "schema_json": schema_json,
        "primary_keys": PRIMARY_KEYS
    }
)

print(f"\nKết quả: {result}")

# Chỉ check nếu có lỗi thật sự (không chứa SUCCESS)
if "SUCCESS" not in result and result.startswith("FAILED:"):
    print(f"Load thất bại!")
    raise Exception(f"Load failed: {result}")
else:
    print(f"Load hoàn tất bảng {TABLE_NAME}!")
# Out:
# StatementMeta(, 2d6bf88e-aad1-4d50-932e-b3da6cb0f5b0, 4, Finished, Available, Finished)
# Bắt đầu load bảng: shift
# Kết quả: FAILED: SUCCESS
# Load hoàn tất bảng shift!
