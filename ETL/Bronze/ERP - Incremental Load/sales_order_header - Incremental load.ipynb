# %%
import json

TABLE_NAME = "sales_order_header"

# Schema dạng dictionary để dễ convert sang JSON
SCHEMA = {
    "fields": [
        {"name": "SalesOrderID", "type": "IntegerType", "nullable": True},
        {"name": "RevisionNumber", "type": "IntegerType", "nullable": True},
        {"name": "OrderDate", "type": "TimestampType", "nullable": True},
        {"name": "DueDate", "type": "TimestampType", "nullable": True},
        {"name": "ShipDate", "type": "TimestampType", "nullable": True},
        {"name": "Status", "type": "IntegerType", "nullable": True},
        {"name": "OnlineOrderFlag", "type": "StringType", "nullable": True},
        {"name": "SalesOrderNumber", "type": "StringType", "nullable": True},
        {"name": "PurchaseOrderNumber", "type": "StringType", "nullable": True},
        {"name": "AccountNumber", "type": "StringType", "nullable": True},
        {"name": "CustomerID", "type": "IntegerType", "nullable": True},
        {"name": "SalesPersonID", "type": "IntegerType", "nullable": True},
        {"name": "TerritoryID", "type": "IntegerType", "nullable": True},
        {"name": "BillToAddressID", "type": "IntegerType", "nullable": True},
        {"name": "ShipToAddressID", "type": "IntegerType", "nullable": True},
        {"name": "ShipMethodID", "type": "IntegerType", "nullable": True},
        {"name": "CreditCardID", "type": "IntegerType", "nullable": True},
        {"name": "CreditCardApprovalCode", "type": "StringType", "nullable": True},
        {"name": "CurrencyRateID", "type": "IntegerType", "nullable": True},
        {"name": "SubTotal", "type": "DecimalType(19,4)", "nullable": True},
        {"name": "TaxAmt", "type": "DecimalType(19,4)", "nullable": True},
        {"name": "Freight", "type": "DecimalType(19,4)", "nullable": True},
        {"name": "TotalDue", "type": "DecimalType(19,4)", "nullable": True},
        {"name": "rowguid", "type": "StringType", "nullable": True},
        {"name": "ModifiedDate", "type": "TimestampType", "nullable": True}
    ]
}

PRIMARY_KEYS = "SalesOrderID"

# %%
print(f"Bắt đầu incremental load bảng: {TABLE_NAME}")

schema_json = json.dumps(SCHEMA)

result = mssparkutils.notebook.run(
    path = "Get Data From Supabase Incremental load",
    timeout_seconds = 300,
    arguments = {
        "table_name": TABLE_NAME,
        "schema_json": schema_json,
        "primary_keys": PRIMARY_KEYS
    }
)

print(f"\nKết quả: {result}")

# Chỉ check nếu có lỗi thật sự (không chứa SUCCESS)
if "SUCCESS" not in result and result.startswith("FAILED:"):
    print(f"Load thất bại!")
    raise Exception(f"Load failed: {result}")
else:
    print(f"Load hoàn tất bảng {TABLE_NAME}!")
