# %%
import json

TABLE_NAME = "employee"

# Schema dạng dictionary để dễ convert sang JSON
SCHEMA = {
    "fields": [
        {"name": "BusinessEntityID", "type": "IntegerType", "nullable": True},
        {"name": "NationalIDNumber", "type": "IntegerType", "nullable": True},
        {"name": "LoginID", "type": "StringType", "nullable": True},
        {"name": "JobTitle", "type": "StringType", "nullable": True},
        {"name": "BirthDate", "type": "DateType", "nullable": True},
        {"name": "MaritalStatus", "type": "StringType", "nullable": True},
        {"name": "Gender", "type": "StringType", "nullable": True},
        {"name": "HireDate", "type": "DateType", "nullable": True},
        {"name": "SalariedFlag", "type": "IntegerType", "nullable": True},
        {"name": "VacationHours", "type": "IntegerType", "nullable": True},
        {"name": "SickLeaveHours", "type": "IntegerType", "nullable": True},
        {"name": "CurrentFlag", "type": "IntegerType", "nullable": True},
        {"name": "rowguid", "type": "StringType", "nullable": True},
        {"name": "ModifiedDate", "type": "TimestampType", "nullable": True}
    ]
}

PRIMARY_KEYS = "BusinessEntityID,NationalIDNumber"

# %%
print(f"Bắt đầu incremental load bảng: {TABLE_NAME}")

schema_json = json.dumps(SCHEMA)

result = mssparkutils.notebook.run(
    path = "Get Data From Supabase Incremental load",
    timeout_seconds = 300,
    arguments = {
        "table_name": TABLE_NAME,
        "schema_json": schema_json,
        "primary_keys": PRIMARY_KEYS
    }
)

print(f"\nKết quả: {result}")

# Chỉ check nếu có lỗi thật sự (không chứa SUCCESS)
if "SUCCESS" not in result and result.startswith("FAILED:"):
    print(f"Load thất bại!")
    raise Exception(f"Load failed: {result}")
else:
    print(f"Load hoàn tất bảng {TABLE_NAME}!")
