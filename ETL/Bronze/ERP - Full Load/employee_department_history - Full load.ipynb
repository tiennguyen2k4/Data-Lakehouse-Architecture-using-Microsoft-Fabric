# %%
import json

TABLE_NAME = "employee_department_history"

# Schema dạng dictionary để dễ convert sang JSON
SCHEMA = {
    "fields": [
        {"name": "BusinessEntityID", "type": "IntegerType", "nullable": True},
        {"name": "DepartmentID", "type": "IntegerType", "nullable": True},
        {"name": "ShiftID", "type": "IntegerType", "nullable": True},
        {"name": "StartDate", "type": "DateType", "nullable": True},
        {"name": "EndDate", "type": "DateType", "nullable": True},
        {"name": "ModifiedDate", "type": "TimestampType", "nullable": True}
    ]
}
# Out:
# StatementMeta(, 3fbe10c5-f632-40fb-9d0e-c92f8344fe64, 3, Finished, Available, Finished)

# %%
print(f"Bắt đầu load bảng: {TABLE_NAME}")

schema_json = json.dumps(SCHEMA)

result = mssparkutils.notebook.run(
    path = "Get Data From Supabase",
    timeout_seconds = 300,
    arguments = {
        "table_name": TABLE_NAME,
        "schema_json": schema_json,
        "drop_before_load": "true"
    }
)

print(f"\nKết quả: {result}")

# Chỉ check nếu có lỗi thật sự (không chứa SUCCESS)
if "SUCCESS" not in result and result.startswith("FAILED:"):
    print(f"Load thất bại!")
    raise Exception(f"Load failed: {result}")
else:
    print(f"Load hoàn tất bảng {TABLE_NAME}!")
# Out:
# StatementMeta(, 3fbe10c5-f632-40fb-9d0e-c92f8344fe64, 4, Finished, Available, Finished)
# Bắt đầu load bảng: employee_department_history
# Kết quả: FAILED: SUCCESS
# Load hoàn tất bảng employee_department_history!
