# %%
import json

TABLE_NAME = "sales_territory"

# Schema dạng dictionary để dễ convert sang JSON
SCHEMA = {
    "fields": [
        {"name": "TerritoryID", "type": "IntegerType", "nullable": True},
        {"name": "Name", "type": "StringType", "nullable": True},
        {"name": "CountryRegionCode", "type": "StringType", "nullable": True},
        {"name": "Group", "type": "StringType", "nullable": True},
        {"name": "SalesYTD", "type": "DecimalType(19,4)", "nullable": True},
        {"name": "SalesLastYear", "type": "DecimalType(19,4)", "nullable": True},
        {"name": "CostLastYear", "type": "DecimalType(19,4)", "nullable": True},
        {"name": "rowguid", "type": "StringType", "nullable": True},
        {"name": "ModifiedDate", "type": "TimestampType", "nullable": True}
    ]
}
# Out:
# StatementMeta(, 62d9b97b-f388-4909-b291-948c2be04739, 3, Finished, Available, Finished)

# %%
print(f"Bắt đầu load bảng: {TABLE_NAME}")

schema_json = json.dumps(SCHEMA)

result = mssparkutils.notebook.run(
    path = "Get Data From Supabase",
    timeout_seconds = 300,
    arguments = {
        "table_name": TABLE_NAME,
        "schema_json": schema_json,
        "drop_before_load": "true"
    }
)

print(f"\nKết quả: {result}")

# Chỉ check nếu có lỗi thật sự (không chứa SUCCESS)
if "SUCCESS" not in result and result.startswith("FAILED:"):
    print(f"Load thất bại!")
    raise Exception(f"Load failed: {result}")
else:
    print(f"Load hoàn tất bảng {TABLE_NAME}!")
# Out:
# StatementMeta(, 62d9b97b-f388-4909-b291-948c2be04739, 4, Finished, Available, Finished)
# Bắt đầu load bảng: sales_territory
# Kết quả: FAILED: SUCCESS
# Load hoàn tất bảng sales_territory!
