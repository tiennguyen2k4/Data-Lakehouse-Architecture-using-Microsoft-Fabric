# %%
import json

TABLE_NAME = "sales_order_detail"

# Schema dạng dictionary để dễ convert sang JSON
SCHEMA = {
    "fields": [
        {"name": "SalesOrderID", "type": "IntegerType", "nullable": True},
        {"name": "SalesOrderDetailID", "type": "IntegerType", "nullable": True},
        {"name": "CarrierTrackingNumber", "type": "StringType", "nullable": True},
        {"name": "OrderQty", "type": "IntegerType", "nullable": True},
        {"name": "ProductID", "type": "IntegerType", "nullable": True},
        {"name": "SpecialOfferID", "type": "IntegerType", "nullable": True},
        {"name": "UnitPrice", "type": "DecimalType(19,4)", "nullable": True},
        {"name": "UnitPriceDiscount", "type": "DecimalType(19,4)", "nullable": True},
        {"name": "LineTotal", "type": "DecimalType(19,4)", "nullable": True},
        {"name": "rowguid", "type": "StringType", "nullable": True},
        {"name": "ModifiedDate", "type": "TimestampType", "nullable": True}
    ]
}
# Out:
# StatementMeta(, 00206f84-9458-45b4-a0c1-18d9d060659b, 3, Finished, Available, Finished)

# %%
print(f"Bắt đầu load bảng: {TABLE_NAME}")

schema_json = json.dumps(SCHEMA)

result = mssparkutils.notebook.run(
    path = "Get Data From Supabase",
    timeout_seconds = 300,
    arguments = {
        "table_name": TABLE_NAME,
        "schema_json": schema_json,
        "drop_before_load": "true"
    }
)

print(f"\nKết quả: {result}")

# Chỉ check nếu có lỗi thật sự (không chứa SUCCESS)
if "SUCCESS" not in result and result.startswith("FAILED:"):
    print(f"Load thất bại!")
    raise Exception(f"Load failed: {result}")
else:
    print(f"Load hoàn tất bảng {TABLE_NAME}!")
# Out:
# StatementMeta(, 00206f84-9458-45b4-a0c1-18d9d060659b, 4, Finished, Available, Finished)
# Bắt đầu load bảng: sales_order_detail
# Kết quả: FAILED: SUCCESS
# Load hoàn tất bảng sales_order_detail!
