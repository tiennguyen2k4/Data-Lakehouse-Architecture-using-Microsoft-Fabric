# %%
import json

TABLE_NAME = "account"

# Schema dạng dictionary để dễ convert sang JSON
SCHEMA = {
    "fields": [
        {"name": "account_id", "type": "IntegerType", "nullable": True},
        {"name": "parent_id", "type": "IntegerType", "nullable": True},
        {"name": "account_code", "type": "IntegerType", "nullable": True},
        {"name": "parent_account_code", "type": "IntegerType", "nullable": True},
        {"name": "account_description", "type": "StringType", "nullable": True},
        {"name": "account_type", "type": "StringType", "nullable": True},
        {"name": "ModifiedDate", "type": "TimestampType", "nullable": True}
    ]
}
# Out:
# StatementMeta(, 10dffd5b-7b2f-4c2f-a344-a75234080930, 3, Finished, Available, Finished)

# %%
print(f"Bắt đầu load bảng: {TABLE_NAME}")

schema_json = json.dumps(SCHEMA)

result = mssparkutils.notebook.run(
    path = "Get Data From Supabase",
    timeout_seconds = 300,
    arguments = {
        "table_name": TABLE_NAME,
        "schema_json": schema_json,
        "drop_before_load": "true"
    }
)

print(f"\nKết quả: {result}")

# Chỉ check nếu có lỗi thật sự (không chứa SUCCESS)
if "SUCCESS" not in result and result.startswith("FAILED:"):
    print(f"Load thất bại!")
    raise Exception(f"Load failed: {result}")
else:
    print(f"Load hoàn tất bảng {TABLE_NAME}!")
# Out:
# StatementMeta(, 10dffd5b-7b2f-4c2f-a344-a75234080930, 4, Finished, Available, Finished)
# Bắt đầu load bảng: account
# Kết quả: FAILED: SUCCESS
# Load hoàn tất bảng account!
