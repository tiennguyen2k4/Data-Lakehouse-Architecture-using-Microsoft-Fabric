# %%
import json

TABLE_NAME = "person"

# Schema dạng dictionary để dễ convert sang JSON
SCHEMA = {
    "fields": [
        {"name": "BusinessEntityID", "type": "IntegerType", "nullable": True},
        {"name": "PersonType", "type": "StringType", "nullable": True},
        {"name": "NameStyle", "type": "StringType", "nullable": True},
        {"name": "Title", "type": "StringType", "nullable": True},
        {"name": "FirstName", "type": "StringType", "nullable": True},
        {"name": "MiddleName", "type": "StringType", "nullable": True},
        {"name": "LastName", "type": "StringType", "nullable": True},
        {"name": "Suffix", "type": "StringType", "nullable": True},
        {"name": "EmailPromotion", "type": "StringType", "nullable": True},
        {"name": "AdditionalContactInfo", "type": "StringType", "nullable": True},
        {"name": "Demographics", "type": "StringType", "nullable": True},
        {"name": "rowguid", "type": "StringType", "nullable": True},
        {"name": "ModifiedDate", "type": "TimestampType", "nullable": True},
        {"name": "BirthDate", "type": "DateType", "nullable": True},
        {"name": "Gender", "type": "StringType", "nullable": True}
    ]
}
# Out:
# StatementMeta(, 724fba86-2cbe-4368-a628-b09e2c7ed4dc, 3, Finished, Available, Finished)

# %%
print(f"Bắt đầu load bảng: {TABLE_NAME}")

schema_json = json.dumps(SCHEMA)

result = mssparkutils.notebook.run(
    path = "Get Data From Supabase",
    timeout_seconds = 300,
    arguments = {
        "table_name": TABLE_NAME,
        "schema_json": schema_json,
        "drop_before_load": "true"
    }
)

print(f"\nKết quả: {result}")

# Chỉ check nếu có lỗi thật sự (không chứa SUCCESS)
if "SUCCESS" not in result and result.startswith("FAILED:"):
    print(f"Load thất bại!")
    raise Exception(f"Load failed: {result}")
else:
    print(f"Load hoàn tất bảng {TABLE_NAME}!")
# Out:
# StatementMeta(, 724fba86-2cbe-4368-a628-b09e2c7ed4dc, 4, Finished, Available, Finished)
# Bắt đầu load bảng: person
# Kết quả: FAILED: SUCCESS
# Load hoàn tất bảng person!
