# %%
import json

TABLE_NAME = "address"

# Schema dạng dictionary để dễ convert sang JSON
SCHEMA = {
    "fields": [
        {"name": "AddressID", "type": "IntegerType", "nullable": True},
        {"name": "AddressLine1", "type": "StringType", "nullable": True},
        {"name": "AddressLine2", "type": "StringType", "nullable": True},
        {"name": "City", "type": "StringType", "nullable": True},
        {"name": "StateProvinceID", "type": "IntegerType", "nullable": True},
        {"name": "PostalCode", "type": "StringType", "nullable": True},
        {"name": "rowguid", "type": "StringType", "nullable": True},
        {"name": "ModifiedDate", "type": "TimestampType", "nullable": True}
    ]
}
# Out:
# StatementMeta(, e59aeccd-fd2d-4045-b763-71519d1b14a9, 5, Finished, Available, Finished)

# %%
print(f"Bắt đầu load bảng: {TABLE_NAME}")

schema_json = json.dumps(SCHEMA)

result = mssparkutils.notebook.run(
    path = "Get Data From Supabase",
    timeout_seconds = 300,
    arguments = {
        "table_name": TABLE_NAME,
        "schema_json": schema_json,
        "drop_before_load": "true"
    }
)

print(f"\nKết quả: {result}")

# Chỉ check nếu có lỗi thật sự (không chứa SUCCESS)
if "SUCCESS" not in result and result.startswith("FAILED:"):
    print(f"Load thất bại!")
    raise Exception(f"Load failed: {result}")
else:
    print(f"Load hoàn tất bảng {TABLE_NAME}!")
# Out:
# StatementMeta(, e59aeccd-fd2d-4045-b763-71519d1b14a9, 6, Finished, Available, Finished)
# Bắt đầu load bảng: address
# Kết quả: FAILED: SUCCESS
# Load hoàn tất bảng address!
