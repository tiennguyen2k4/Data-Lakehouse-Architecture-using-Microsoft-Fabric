# %%
import json

TABLE_NAME = "product_inventory"

# Schema dạng dictionary để dễ convert sang JSON
SCHEMA = {
    "fields": [
        {"name": "ProductID", "type": "IntegerType", "nullable": True},
        {"name": "LocationID", "type": "IntegerType", "nullable": True},
        {"name": "Shelf", "type": "StringType", "nullable": True},
        {"name": "Bin", "type": "IntegerType", "nullable": True},
        {"name": "Quantity", "type": "IntegerType", "nullable": True},
        {"name": "rowguid", "type": "StringType", "nullable": True},
        {"name": "ModifiedDate", "type": "TimestampType", "nullable": True}
    ]
}
# Out:
# StatementMeta(, 9033da44-18c2-497a-a14a-da60c9502f1b, 3, Finished, Available, Finished)

# %%
print(f"Bắt đầu load bảng: {TABLE_NAME}")

schema_json = json.dumps(SCHEMA)

result = mssparkutils.notebook.run(
    path = "Get Data From Supabase",
    timeout_seconds = 300,
    arguments = {
        "table_name": TABLE_NAME,
        "schema_json": schema_json,
        "drop_before_load": "true"
    }
)

print(f"\nKết quả: {result}")

# Chỉ check nếu có lỗi thật sự (không chứa SUCCESS)
if "SUCCESS" not in result and result.startswith("FAILED:"):
    print(f"Load thất bại!")
    raise Exception(f"Load failed: {result}")
else:
    print(f"Load hoàn tất bảng {TABLE_NAME}!")
# Out:
# StatementMeta(, 9033da44-18c2-497a-a14a-da60c9502f1b, 4, Finished, Available, Finished)
# Bắt đầu load bảng: product_inventory
# Kết quả: FAILED: SUCCESS
# Load hoàn tất bảng product_inventory!
